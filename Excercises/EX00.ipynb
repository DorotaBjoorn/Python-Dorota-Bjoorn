# %% [markdown]
# ## 1a

# %%
a = 3
b = 4

import math
math.sqrt(a*a+b*b)
# Out:
# 5.0

# %% [markdown]
# ## 1b

# %%
a = 5
c = 7

import math
print(f"{math.sqrt(c*c-a*a):.1f}")
# Out:
# 4.9

# %% [markdown]
# ## 2

# %%
days = 365
hits = 300
accuracy = hits/days*100

print(f"The accuracy is {accuracy:.0f} %")
# Out:
# The accuracy is 82 %

# %% [markdown]
# ## 3

# %%
TP = 2
FP = 2
FN = 11
TN = 985

accuracy = (100*((TP+TN)/(TP+TN+FP+FN)))

print(f"Accuracy is {accuracy:.0f} %")
# Out:
# Accuracy is 99 %
